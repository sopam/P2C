# %%
import pandas as pd

# %%
#src_file = 'C3G_adult_10_smallest_L1.csv'
#src_file = 'MC3G_adult_10_smallest_L1.csv'

#src_file = 'C3G_adult_10_smallest_L2.csv'
src_file = 'MC3G_adult_10_smallest_L1.csv'
src_path = 'Counterfactuals/'

# %%
df_src = pd.read_csv(src_path+src_file)
df_src
# Out:
#    Unnamed: 0      Marital_Status  Capital_gain  Education_num Relationship  \
# 0           0  Married-civ-spouse          5060              9      Husband
# 1           1  Married-civ-spouse          5178              9      Husband
# 2           2  Married-civ-spouse          5455              9      Husband
# 3           3  Married-civ-spouse          5556              9      Husband
# 4           4  Married-civ-spouse          5721              9      Husband
# 5           5  Married-civ-spouse          6097              9      Husband
# 6           6  Married-civ-spouse          6360              9      Husband
# 7           7  Married-civ-spouse          6418              9      Husband
# 8           8  Married-civ-spouse          6497              9      Husband
# 9           9  Married-civ-spouse          6514              9      Husband
#
#     Sex  Hours_per_week Native_country  Age  Workclass   Race  Fnlwgt  \
# ...

# %%
df_src['L1'].mean()
# Out:
# 0.8158321126066033
